# %%
import pandas as pd

# %%
df = pd.read_pickle("data/prod_archive/05-02-2022/cumulative_tracking_05-02-2022.pkl")

# %%
df[-50:]
# Out:
#             clones_unique  clones_total  views_unique  views_total  \
# 2022-03-10              3             4             0            0
# 2022-03-10              1             2             0            0
# 2022-03-10              1             2             1            1
# 2022-03-10              3             4             2            3
# 2022-03-10              1             2             1            1
# 2022-03-10              1             2             1            2
# 2022-03-11             10            16             4            4
# 2022-03-11              4             5             2            6
# 2022-03-11              7            10            10           15
# 2022-03-11              5             5             1            1
# 2022-03-11              5             5             2            4
# 2022-03-11              4             5             1            2
# 2022-03-11              4             5             1            1
# ...

# %%
today_str = "04-22-2022"
day_df = pd.read_pickle(f"data/daily_archive/{today_str}/daily_tracking_{today_str}.pkl")

# %%
day_df[:50]
# Out:
#             clones_unique  clones_total  views_unique  views_total  \
# 2022-04-21              0             0             7           13
# 2022-04-21              0             0             1            1
# 2022-04-21              1            12            14           46
# 2022-04-21              4             5             1            2
# 2022-04-21              1             1             0            0
# 2022-04-21              0             0             1            1
# 2022-04-21              1             1             2            2
# 2022-04-21              2             2             2           13
# 2022-04-21              1             1             1            1
# 2022-04-21              2             2             3            3
# 2022-04-21              1             1             1            1
# 2022-04-21              1             1             1            1
# 2022-04-21              0             0             3           13
# ...

# %%
today_str = "04-21-2022"
day_df2 = pd.read_pickle(f"data/daily_archive/{today_str}/daily_tracking_{today_str}.pkl")

# %%
day_df2[:50]
# Out:
#             clones_unique  clones_total  views_unique  views_total  \
# 2022-04-20              6             8             4           14
# 2022-04-20              3             3             2            2
# 2022-04-20              5             8             6            7
# 2022-04-20              1             1             0            0
# 2022-04-20              1             1             3           33
# 2022-04-20              2             2             1            4
# 2022-04-20              0             0             1            2
# 2022-04-20              1             1             2           18
# 2022-04-20              1             1             1            1
# 2022-04-20              0             0             1            1
# 2022-04-20              0             0             1            1
# 2022-04-20              0             0             0            0
# 2022-04-20              3             3             2            6
# ...

# %%
(day_df == day_df2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-d90a1fb66cb2> in <module>()
# ----> 1 (day_df == day_df2)
#
# /usr/local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in f(self, other)
#    1565             if not self._indexed_same(other):
#    1566                 raise ValueError(
# -> 1567                     "Can only compare identically-labeled " "DataFrame objects"
#    1568                 )
#    1569             return dispatch_to_series(self, other, func, str_rep)
#
# ValueError: Can only compare identically-labeled DataFrame objects
